# %% [markdown]
# # Hand Written Digit Classification - Classification Analysis

# %% [markdown]
# -------------

# %% [markdown]
# ## **Objective**

# %% [markdown]
# ### to classify the writtend digit using this classification model

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Import Data**

# %%
from sklearn.datasets import load_digits

# %%
df = load_digits()

# %% [markdown]
# ## **Describe Data**

# %%
_, axes = plt.subplots(rows=1,ncols=4,figsiz=(10,3))

# %% [markdown]
# ## **Data Visualization**

# %%
for ax,image, label in zip(axes, df.images, df.target):
    ax.set_axis_off()
    ax.inshow(image,cmap-plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training : %i"%label)

# %% [markdown]
# ## **Data Preprocessing**

# %%
df.images.shape

# %%
df.images[0]

# %%
df.images[0].shape

# %%
len(df.images)

# %%
n_samples=len(df.images)
data = df.images.reshape(n_samples, -1)

# %%
data[0]

# %%
data[0].shape

# %%
data.shape

# %% [markdown]
# # Scaling Image Data

# %%
data.min()

# %%
data.max()

# %%
data=data/16

# %%
data.min()

# %%
data.max()

# %%
data[0]

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(data,df.target,test_size=0.3)

# %% [markdown]
# ## **Train Test Split**

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape

# %% [markdown]
# ## **Modeling**

# %% [markdown]
# ## **Model Evaluation**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,y_train)

# %% [markdown]
# ## **Prediction**

# %%
y_pred = rf.predict(X_test)

# %%
y_pred

# %% [markdown]
# # Model Accuracy

# %%
from sklearn.matrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test,y_pred)

# %%
print(classification_report(y_test,y_pred))
